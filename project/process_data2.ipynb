# %%
import pandas as pd

raw_df = pd.read_csv('data.csv')
# Out:
# c:\users\marsh\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (61,63,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
raw_df.head()
# Out:
#    Row Sample Name                    Transaction Id  \
# 0    1    All Data  edea5e53aecbab51c95db5daf2e8a3ed
# 1    2    All Data  3ef6d83d97af2af27b865a9313cb3606
# 2    3    All Data  990495633485f1dfc13bbee515d11e97
# 3    4    All Data  c5c9dd1378006078865dd387cc427f6c
# 4    5    All Data  dca05a90ed9a01bff3b2e9dda0ac9701
#
#                         Anon Student Id  Session Id             Time  \
# 0  Stu_0012ae7d5d1993619f0bad91630b7c79     3519200   2/7/2006 14:12
# 1  Stu_0012ae7d5d1993619f0bad91630b7c79     3519200   2/7/2006 14:13
# 2  Stu_0012ae7d5d1993619f0bad91630b7c79     3519200   2/7/2006 14:14
# 3  Stu_0012ae7d5d1993619f0bad91630b7c79     3519239   2/7/2006 14:23
# 4  Stu_00176143fc2991346939888160a9b1ce     2572205  11/8/2005 10:20
#
#     Time Zone  Duration (sec) Student Response Type  Student Response Subtype  \
# 0  US/Eastern           576.0          HINT_REQUEST                       NaN
# ...

# %%
raw_df.columns
# Out:
# Index(['Row', 'Sample Name', 'Transaction Id', 'Anon Student Id', 'Session Id',
#        'Time', 'Time Zone', 'Duration (sec)', 'Student Response Type',
#        'Student Response Subtype', 'Tutor Response Type',
#        'Tutor Response Subtype', 'Level (Curriculum)', 'Problem Name',
#        'Problem View', 'Problem Start Time', 'Step Name', 'Attempt At Step',
#        'Is Last Attempt', 'Outcome', 'Selection', 'Action', 'Input',
#        'Feedback Text', 'Feedback Classification', 'Help Level',
#        'Total Num Hints', 'KC (WPI-Apr-2005)', 'KC Category (WPI-Apr-2005)',
#        'KC (WPI-Apr-2005)_1', 'KC Category (WPI-Apr-2005)_2',
#        'KC (WPI-Apr-2005)_3', 'KC Category (WPI-Apr-2005)_4',
#        'KC (WPI-Apr-2005)_5', 'KC Category (WPI-Apr-2005)_6',
#        'KC (WPI-Apr-2005)_7', 'KC Category (WPI-Apr-2005)_8',
#        'KC (WPI-Apr-2005)_9', 'KC Category (WPI-Apr-2005)_10',
#        'KC (skills_from_dataframe)', 'KC Category (skills_from_dataframe)',
# ...

# %%
len(raw_df['Anon Student Id'].unique())
# Out:
# 3136

# %%
a = raw_df['Anon Student Id'].unique()
dict(zip(a, range(1, len(a))))
# Out:
# {'Stu_0012ae7d5d1993619f0bad91630b7c79': 1,
#  'Stu_00176143fc2991346939888160a9b1ce': 2,
#  'Stu_001c92cd0ee0ea92a7ec2c5d027ab034': 3,
#  'Stu_001d187b1b375fe98b88696b250177f0': 4,
#  'Stu_00291360813ec3b3bc1133a40e2e7590': 5,
#  'Stu_003299de9d0151b8b337382d13c1ddfa': 6,
#  'Stu_0059d29b5c1d5725c5e7c81944b31d73': 7,
#  'Stu_00847b7cad41b6ec3b8e5921030d72c0': 8,
#  'Stu_00929971627d4252a152cb20f93a1f5b': 9,
#  'Stu_00a049fce789a37978752a2cdf9fdf23': 10,
#  'Stu_00b514ebf11d2662e9d86040541d8b40': 11,
#  'Stu_00f752658500e48ecc6f4d1176154dbb': 12,
#  'Stu_010a1dfe887f0a62841b004338abf294': 13,
#  'Stu_010da736b426561d1b99ff275b534380': 14,
#  'Stu_010ec51612bca49e0eff228ae6567ea9': 15,
#  'Stu_0111a875cf2fe278195b1fc910316463': 16,
#  'Stu_01164e0cd443910b642f4ec8bfd2ca2e': 17,
#  'Stu_011759cca98dc3036054782db3516d72': 18,
#  'Stu_014e7fe7152531abeee6602772c48987': 19,
#  'Stu_01643bd97fdac787fd4c9dcca0b52ba9': 20,
#  'Stu_01653a6a815dc168b89e948d05fa016d': 21,
# ...
